# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import urllib.parse
from copy import copy
import requests
import re
import json
import urllib.request

# %%
df = pd.read_csv('Sébastien_Ogier.csv') 
df
# Out:
#       Unnamed: 0           Driver                           Name  \
# 0              0  Sébastien Ogier  Rallye Automobile Monte-Carlo
# 1              1  Sébastien Ogier  Rallye Automobile Monte-Carlo
# 2              2  Sébastien Ogier  Rallye Automobile Monte-Carlo
# 3              3  Sébastien Ogier  Rallye Automobile Monte-Carlo
# 4              4  Sébastien Ogier  Rallye Automobile Monte-Carlo
# ...          ...              ...                            ...
# 3063        3063  Sébastien Ogier        Neste Oil Rally Finland
# 3064        3064  Sébastien Ogier        Neste Oil Rally Finland
# 3065        3065  Sébastien Ogier        Neste Oil Rally Finland
# 3066        3066  Sébastien Ogier        Neste Oil Rally Finland
# 3067        3067  Sébastien Ogier        Neste Oil Rally Finland
#
#                                                     URL  Year Race_Result  \
# 0     /entryinfo/77787-rallye-automobile-monte-carlo...  2023           1
# 1     /entryinfo/77787-rallye-automobile-monte-carlo...  2023           1
# 2     /entryinfo/77787-rallye-automobile-monte-carlo...  2023           1
# 3     /entryinfo/77787-rallye-automobile-monte-carlo...  2023           1
# 4     /entryinfo/77787-rallye-automobile-monte-carlo...  2023           1
# ...                                                 ...   ...         ...
# 3063  /entryinfo/157-neste-oil-rally-finland-2008/17...  2008           3
# 3064  /entryinfo/157-neste-oil-rally-finland-2008/17...  2008           3
# 3065  /entryinfo/157-neste-oil-rally-finland-2008/17...  2008           3
# 3066  /entryinfo/157-neste-oil-rally-finland-2008/17...  2008           3
# 3067  /entryinfo/157-neste-oil-rally-finland-2008/17...  2008           3
#
#      DNG_Reason                                            Php_url  p_overall  \
# 0          Null  https://www.ewrc-results.com/inc/json_driverin...          1
# 1          Null  https://www.ewrc-results.com/inc/json_driverin...          1
# 2          Null  https://www.ewrc-results.com/inc/json_driverin...          1
# 3          Null  https://www.ewrc-results.com/inc/json_driverin...          1
# 4          Null  https://www.ewrc-results.com/inc/json_driverin...          1
# ...         ...                                                ...        ...
# 3063       Null  https://www.ewrc-results.com/inc/json_driverin...         27
# 3064       Null  https://www.ewrc-results.com/inc/json_driverin...         26
# 3065       Null  https://www.ewrc-results.com/inc/json_driverin...         35
# 3066       Null  https://www.ewrc-results.com/inc/json_driverin...         36
# 3067       Null  https://www.ewrc-results.com/inc/json_driverin...         35
#
#       stage ssname
# 0         1    SS1
# 1         1    SS2
# 2         1    SS3
# 3         1    SS4
# 4         1    SS5
# ...     ...    ...
# 3063     22   SS20
# 3064     20   SS21
# 3065     71   SS22
# 3066     53   SS23
# 3067     52   SS24
#
# [3068 rows x 11 columns]

# %% [markdown]
# # Total Race Event Wins

# %%
df.groupby(['Name','Year']).size().reset_index(name='count')
# Out:
#                         Name  Year  count
# 0            ACI Rally Monza  2020     14
# 1    ADAC Rallye Deutschland  2010     19
# 2    ADAC Rallye Deutschland  2011     19
# 3    ADAC Rallye Deutschland  2012     15
# 4    ADAC Rallye Deutschland  2013     15
# ..                       ...   ...    ...
# 164     XION Rally Argentina  2015     12
# 165     XION Rally Argentina  2019     17
# 166      YPF Rally Argentina  2016     18
# 167      YPF Rally Argentina  2017     18
# 168      YPF Rally Argentina  2018     18
#
# [169 rows x 3 columns]

# %%
df.loc[df['Race_Result'] == "1"].groupby(['Name','Year']).size().reset_index(name='count')
# Out:
#                        Name  Year  count
# 0           ACI Rally Monza  2020     14
# 1   ADAC Rallye Deutschland  2011     19
# 2   ADAC Rallye Deutschland  2013     15
# 3   ADAC Rallye Deutschland  2015     21
# 4   ADAC Rallye Deutschland  2016     18
# ..                      ...   ...    ...
# 67           Wales Rally GB  2012     19
# 68           Wales Rally GB  2013     22
# 69           Wales Rally GB  2014     23
# 70           Wales Rally GB  2015     19
# 71     XION Rally Argentina  2015     12
#
# [72 rows x 3 columns]

# %%
72/169
# Out:
# 0.4260355029585799

# %% [markdown]
# # Total Stage Wins

# %%
df.count()
# Out:
# Unnamed: 0     3068
# Driver         3068
# Name           3068
# URL            3068
# Year           3068
# Race_Result    3068
# DNG_Reason     3068
# Php_url        3068
# p_overall      3068
# stage          3068
# ssname         3068
# dtype: int64

# %%
df.loc[df['stage'] == 1].count()
# Out:
# Unnamed: 0     668
# Driver         668
# Name           668
# URL            668
# Year           668
# Race_Result    668
# DNG_Reason     668
# Php_url        668
# p_overall      668
# stage          668
# ssname         668
# dtype: int64

# %%
668/3068
# Out:
# 0.21773142112125163

# %% [markdown]
# # How many DNF?

# %%
df.loc[df['DNG_Reason'] != "Null"].groupby(['Name','Year'])['DNG_Reason'].size().reset_index(name='count')
# Out:
#                                          Name  Year  count
# 0                     ADAC Rallye Deutschland  2014      7
# 1                          FxPro Cyprus Rally  2009     13
# 2                         Neste Rally Finland  2017      3
# 3   Orlen Platinum Rally Poland - Rajd Polski  2009     15
# 4                     Rally Guanajuato Mexico  2011     19
# 5                       Rally Turkey Marmaris  2020     10
# 6                     Rally d'Italia Sardegna  2009     12
# 7                      Rally of Great Britain  2009     15
# 8         RallyRACC Catalunya - Costa Daurada  2011     16
# 9         RallyRACC Catalunya - Costa Daurada  2012      5
# 10        RallyRACC Catalunya - Costa Daurada  2015     22
# 11              Rallye Automobile Monte-Carlo  2012      9
# 12                 Vodafone Rally de Portugal  2018     19
# 13                             Wales Rally GB  2010      7

# %%
13/169
# Out:
# 0.07692307692307693

# %% [markdown]
# # Find smaller accidents and come-backs

# %%
grouped = df.groupby(['Name','Year'])
results = []

for name, group in grouped:
    group['diff'] = group['stage'].diff()
    
    for index, row in group.iterrows():
        if row['diff'] > 20 or row['diff'] < -20:
            results.append([row['Name'], row['Year'], row['ssname'], row['diff']])
            
results
# Out:
# [['ADAC Rallye Deutschland', 2013, 'SS3', 30.0],
#  ['ADAC Rallye Deutschland', 2013, 'SS4', 23.0],
#  ['ADAC Rallye Deutschland', 2013, 'SS9', -56.0],
#  ['ADAC Rallye Deutschland', 2014, 'SS6', 80.0],
#  ['ADAC Rallye Deutschland', 2014, 'SS7', -78.0],
#  ['Arctic Rally Finland Powered by CapitalBox', 2021, 'SS8', 42.0],
#  ['Arctic Rally Finland Powered by CapitalBox', 2021, 'SS9', -39.0],
#  ['FORUM8 Rally Japan', 2022, 'SS2', 32.0],
#  ['FORUM8 Rally Japan', 2022, 'SS4', -31.0],
#  ['Neste Oil Rally Finland', 2008, 'SS22', 51.0],
#  ['Neste Rally Finland', 2016, 'SS10', 64.0],
#  ['Neste Rally Finland', 2016, 'SS11', -67.0],
#  ['Rally Argentina', 2009, 'SS19', -24.0],
#  ['Rally Italia Sardegna', 2019, 'SS5', 67.0],
#  ['Rally Italia Sardegna', 2019, 'SS10', -59.0],
#  ['Rally Italia Sardegna', 2019, 'SS11', 60.0],
#  ['Rally Italia Sardegna', 2019, 'SS13', -58.0],
#  ['Rally Italia Sardegna', 2019, 'SS16', 25.0],
#  ['Rally Italia Sardegna', 2019, 'SS17', -28.0],
#  ['Rally Italia Sardegna', 2019, 'SS18', 23.0],
#  ['Rally Italia Sardegna', 2019, 'SS19', -25.0],
#  ['Rally Norway', 2009, 'SS14', -22.0],
#  ['Rally Norway', 2009, 'SS21', 23.0],
#  ['Rally Sweden', 2014, 'SS8', 35.0],
#  ['Rally Sweden', 2014, 'SS9', -35.0],
#  ['Rally Sweden', 2019, 'SS6', 41.0],
#  ['Rally Sweden', 2019, 'SS9', -48.0],
#  ['Rally Sweden', 2019, 'SS18', 22.0],
#  ['Rally Turkey Marmaris', 2018, 'SS11', 31.0],
#  ['Rally Turkey Marmaris', 2018, 'SS14', -24.0],
#  ["Rally d'Italia Sardegna", 2009, 'SS5', 31.0],
#  ["Rally d'Italia Sardegna", 2009, 'SS7', -26.0],
#  ["Rally d'Italia Sardegna", 2009, 'SS10', 30.0],
#  ['Rally of Great Britain', 2009, 'SS15', 47.0],
#  ['Rally of Turkey', 2010, 'SS15', 29.0],
#  ['Rally of Turkey', 2010, 'SS16', -30.0],
#  ['RallyRACC Catalunya - Costa Daurada', 2010, 'SS8', 41.0],
#  ['RallyRACC Catalunya - Costa Daurada', 2010, 'SS9', -29.0],
#  ['RallyRACC Catalunya - Costa Daurada', 2019, 'SS2', 25.0],
#  ['Rallye de France - Alsace', 2010, 'SS15', 31.0],
#  ['Rallye de France - Alsace', 2010, 'SS17', -40.0],
#  ['Rallye de France - Alsace', 2014, 'SS2', 51.0],
#  ['Rallye de France - Alsace', 2014, 'SS3', -42.0],
#  ['Repco Rally Australia', 2011, 'SS25', 22.0],
#  ['Tour de Corse', 2015, 'SS3', 86.0],
#  ['Tour de Corse', 2015, 'SS5', -84.0],
#  ['Vodafone Rally de Portugal', 2009, 'SS8', 53.0],
#  ['Vodafone Rally de Portugal', 2009, 'SS14', -31.0],
#  ['Vodafone Rally de Portugal', 2018, 'SS5', 48.0],
#  ['Vodafone Rally de Portugal', 2018, 'SS10', -50.0],
#  ['Vodafone Rally de Portugal', 2022, 'SS6', 29.0],
#  ['Vodafone Rally de Portugal', 2022, 'SS7', 31.0],
#  ['Vodafone Rally de Portugal', 2022, 'SS10', -49.0],
#  ['Vodafone Rally de Portugal', 2022, 'SS11', 52.0],
#  ['Vodafone Rally de Portugal', 2022, 'SS17', -47.0],
#  ['Wales Rally GB', 2008, 'SS9', 37.0],
#  ['Wales Rally GB', 2008, 'SS16', -33.0],
#  ['Wales Rally GB', 2011, 'SS4', -57.0],
#  ['XION Rally Argentina', 2015, 'SS2', 30.0],
#  ['XION Rally Argentina', 2015, 'SS7', -32.0]]
